# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
candidate_classes_dbpedia_df = pd.read_csv('candidate_classes_dbpedia_df.csv')
candidate_classes_dbpedia_df = candidate_classes_dbpedia_df.set_index('item')
candidate_classes_dbpedia_df
# Out:
#                                  dbpedia_class
# item
# Lorenzo Thomas                          Person
# Lorenzo Thomas                           Agent
# Lorenzo Thomas                  MilitaryPerson
# Artaxerxes II                              NaN
# Connecticut                              Place
# ...                                        ...
# Marquise Hill           AmericanFootballPlayer
# Marquise Hill                          Athlete
# Marquise Hill           GridironFootballPlayer
# Corten                                     NaN
# Jervis shopping centre                     NaN
#
# [3144 rows x 1 columns]

# %%
with open('wiki_class_priority_UNER_dict_list.json','r') as f:
    UNER_classes = json.load(f)

# %%
for entry in UNER_classes:
    if entry['title'] == '':
        continue
    classes = candidate_classes_dbpedia_df.loc[entry['title']]['dbpedia_class']
    if type(classes) == float and np.isnan(classes):
        entry['dbpedia_classes'] = 'None'
    elif type(classes) == str:
        entry['dbpedia_classes'] = [classes]
    else:
        entry['dbpedia_classes'] = list(classes)

# %%
candidate_classes_uner_dbpedia_df = pd.DataFrame(UNER_classes)
candidate_classes_uner_dbpedia_df[candidate_classes_uner_dbpedia_df['dbpedia_classes'] != 'None']
# Out:
#                       title  \
# 0            Lorenzo Thomas
# 2               Connecticut
# 4               Krugersdorp
# 6     Kurung Kumey district
# 7            Uganda Martyrs
# ...                     ...
# 1200        Robert Zemeckis
# 1201       James Counsilman
# 1202       Battle of Dak To
# 1204      Garden House riot
# 1205          Marquise Hill
#
#                                              candidates  \
# 0     [[Name-Person-Name, 3], [Name-Person-Name, 3],...
# 2                    [[Name-Location-GPE-GPE_Other, 4]]
# 4     [[Name-Location-GPE-City, 5], [Name-Location-G...
# 6                    [[Name-Location-GPE-GPE_Other, 4]]
# 7            [[Name-Organization-Show_Organization, 5]]
# ...                                                 ...
# 1200  [[Name-Person-Name, 3], [Name-Person-Name, 3],...
# 1201  [[Name-Person-Name, 3], [Name-Person-Name, 3],...
# 1202  [[Name-Event-Historical_Event, 2], [Name-Event...
# 1204                                [[Name-Disease, 2]]
# 1205  [[Name-Person-Name, 3], [Name-Person-Name, 3],...
#
#                                        chosen_one  \
# 0                         [[3, Name-Person-Name]]
# 2              [[4, Name-Location-GPE-GPE_Other]]
# 4                   [[5, Name-Location-GPE-City]]
# 6              [[4, Name-Location-GPE-GPE_Other]]
# 7      [[5, Name-Organization-Show_Organization]]
# ...                                           ...
# 1200                      [[3, Name-Person-Name]]
# 1201                      [[3, Name-Person-Name]]
# 1202  [[4, Name-Event-Occasion-MilitaryConflict]]
# 1204                          [[2, Name-Disease]]
# 1205                      [[3, Name-Person-Name]]
#
#                                         dbpedia_classes
# 0                       [Person, Agent, MilitaryPerson]
# 2     [Place, Location, AdministrativeRegion, Popula...
# 4     [Place, Location, City, PopulatedPlace, Settle...
# 6                                          [Settlement]
# 7                                                [Band]
# ...                                                 ...
# 1200                                    [Person, Agent]
# 1201      [Person, Agent, Coach, CollegeCoach, Swimmer]
# 1202  [Event, MilitaryConflict, SocietalEvent, Telev...
# 1204                                          [Disease]
# 1205  [Person, Agent, AmericanFootballPlayer, Athlet...
#
# [944 rows x 4 columns]

# %%
candidate_classes_uner_dbpedia_df.to_csv('candidate_classes_uner_dbpedia_df.csv', index=False)
